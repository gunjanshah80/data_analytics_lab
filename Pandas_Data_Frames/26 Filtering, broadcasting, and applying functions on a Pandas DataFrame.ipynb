# %% [markdown]
# Let's import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Let's load a dataset containing information about restaurants available on the Swiggy food delivery platform. Note that this data is compiled by third-party sources and isn't affiliated with Swiggy or any of the mentioned restaurants.

# %%
df = pd.read_csv('swiggy.csv')
df.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 4  249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# 3  80 Feet Road             57
# 4  80 Feet Road             63

# %%
df = pd.read_csv('swiggy.csv', index_col = 'ID')
df.head()
# Out:
#             Area       City         Restaurant  Price  Avg ratings  \
# ID
# 211  Koramangala  Bangalore        Tandoor Hut  300.0          4.4
# 221  Koramangala  Bangalore      Tunday Kababi  300.0          4.1
# 246    Jogupalya  Bangalore            Kim Lee  650.0          4.4
# 248  Indiranagar  Bangalore  New Punjabi Hotel  250.0          3.9
# 249  Indiranagar  Bangalore                Nh8  350.0          4.0
#
#      Total ratings                                          Food type  \
# ID
# 211            100          Biryani,Chinese,North Indian,South Indian
# 221            100                                   Mughlai,Lucknowi
# 246            100                                            Chinese
# 248            500               North Indian,Punjabi,Tandoor,Chinese
# 249             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#           Address  Delivery time
# ID
# 211     5Th Block             59
# 221     5Th Block             56
# 246   Double Road             50
# 248  80 Feet Road             57
# 249  80 Feet Road             63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8680 entries, 211 to 466488
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Area           8680 non-null   object
#  1   City           8680 non-null   object
#  2   Restaurant     8680 non-null   object
#  3   Price          8680 non-null   float64
#  4   Avg ratings    8680 non-null   float64
#  5   Total ratings  8680 non-null   int64
#  6   Food type      8680 non-null   object
#  7   Address        8680 non-null   object
#  8   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 678.1+ KB

# %% [markdown]
# The 'Price' column denotes the average food prices at the restaurant. The 'Delivery time' column denotes the average delivery times at the restaurant.
#
# Let's begin by finding all restaurants with an average rating that is 4.0 or higher.

# %%
df['Avg ratings'] >= 4.0
# Out:
# ID
# 211        True
# 221        True
# 246        True
# 248       False
# 249        True
#           ...
# 464626    False
# 465835    False
# 465872    False
# 465990    False
# 466488    False
# Name: Avg ratings, Length: 8680, dtype: bool

# %%
df[df['Avg ratings'] >= 4.0]
# Out:
#                Area       City              Restaurant  Price  Avg ratings  \
# ID
# 211     Koramangala  Bangalore             Tandoor Hut  300.0          4.4
# 221     Koramangala  Bangalore           Tunday Kababi  300.0          4.1
# 246       Jogupalya  Bangalore                 Kim Lee  650.0          4.4
# 249     Indiranagar  Bangalore                     Nh8  350.0          4.0
# 254     Indiranagar  Bangalore                   Treat  800.0          4.5
# ...             ...        ...                     ...    ...          ...
# 442347    Lake Town    Kolkata                Savister  250.0          4.3
# 444297    Vastrapur  Ahmedabad              Chup Chaap  200.0          4.8
# 446079    Vastrapur  Ahmedabad  Rotlo Gujarati Rasthal  300.0          4.2
# 448359    Vastrapur  Ahmedabad           P Se Pavbhaji  150.0          4.4
# 450543     Perambur    Chennai                  Afresh  100.0          5.0
#
#         Total ratings                                          Food type  \
# ID
# 211               100          Biryani,Chinese,North Indian,South Indian
# 221               100                                   Mughlai,Lucknowi
# 246               100                                            Chinese
# 249                50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
# 254               100                               Mughlai,North Indian
# ...               ...                                                ...
# 442347             20                                   Snacks,Beverages
# 444297             20  Indian,Tandoor,Beverages,North Indian,Chinese,...
# 446079             20                                           Gujarati
# 448359             20  Street Food,Fast Food,Combo,Snacks,Beverages,D...
# 450543             20             Healthy Food,Salads,Desserts,Beverages
#
#               Address  Delivery time
# ID
# 211         5Th Block             59
# 221         5Th Block             56
# 246       Double Road             50
# 249      80 Feet Road             63
# 254     100 Feet Road             56
# ...               ...            ...
# 442347      Lake Town             87
# 444297      Vastrapur             52
# 446079      Vastrapur             47
# 448359      Vastrapur             50
# 450543       Perambur             50
#
# [4005 rows x 9 columns]

# %% [markdown]
# Let's restrict this to restaurants that have at least 500 ratings

# %%
df[(df['Avg ratings'] >= 4.0) & (df['Total ratings'] >= 500)]
# Out:
#                   Area       City                    Restaurant   Price  \
# ID
# 258        Indiranagar  Bangalore     Chinita Real Mexican Food  1000.0
# 308        Koramangala  Bangalore                    Bangaliana   300.0
# 446         Cooke Town  Bangalore  Altaf'S Chillies Restaurants   250.0
# 1050         Jayanagar  Bangalore             Nagarjuna Chimney   800.0
# 1547        Masab Tank  Hyderabad                     Dine Hill   400.0
# ...                ...        ...                           ...     ...
# 395439          Adajan      Surat      Shree Kathiyawadi Khadki   250.0
# 395519  Himayath Nagar  Hyderabad                    Wahh Chaap   300.0
# 395927       Hatibagan    Kolkata        Nic Natural Ice Creams   120.0
# 397744             Nsp      Delhi               Modern Caterers   300.0
# 399576         Kondhwa       Pune              Jyoti Restaurant   200.0
#
#         Avg ratings  Total ratings  \
# ID
# 258             4.5            500
# 308             4.0            500
# 446             4.3            500
# 1050            4.2           1000
# 1547            4.1            500
# ...             ...            ...
# 395439          4.3           1000
# 395519          4.1            500
# 395927          4.8            500
# 397744          4.2           1000
# 399576          4.1           1000
#
#                                                 Food type          Address  \
# ID
# 258                              Mexican,Beverages,Salads      Double Road
# 308                                               Bengali        7Th Block
# 446                                  North Indian,Chinese       Cooke Town
# 1050    Seafood,Andhra,Biryani,South Indian,Combo,Dess...        3Rd Block
# 1547                 Arabian,Biryani,North Indian,Chinese      Ahmed Nagar
# ...                                                   ...              ...
# 395439  Gujarati,Thalis,North Indian,Rajasthani,Desser...           Adajan
# 395519                               North Indian,Biryani   Himayath Nagar
# 395927                                 Ice Cream,Desserts  Arabinda Sarani
# 397744      North Indian,Chinese,Snacks,Beverages,Punjabi              Nsp
# 399576  North Indian,South Indian,Beverages,Ice Cream,...          Kondhwa
#
#         Delivery time
# ID
# 258                53
# 308                57
# 446                55
# 1050               48
# 1547               49
# ...               ...
# 395439             46
# 395519             31
# 395927             37
# 397744             46
# 399576             62
#
# [850 rows x 9 columns]

# %% [markdown]
# Let's find fast and affordable restaurants which have a delivery time of less than 30 minutes and a price point of less than 300

# %%
df[(df['Delivery time'] < 30) & (df['Price'] < 300)]
# Out:
#                   Area       City                Restaurant  Price  \
# ID
# 6745              Koti  Hyderabad             Tibbs Frankie  150.0
# 6851             Abids  Hyderabad           Agrawala Sweets  250.0
# 9757        Pitam Pura      Delhi             Shut Up & Eat  250.0
# 12434           Mumbai     Mumbai                J.J Jalebi  100.0
# 32003     Himayatnagar  Hyderabad                 Rice Bowl  200.0
# ...                ...        ...                       ...    ...
# 366790        Jam Bagh  Hyderabad        Subbu Mirchi Point  100.0
# 372444    Gulbai Tekra  Ahmedabad      New Girish Coldrinks  200.0
# 382460  Himayath Nagar  Hyderabad   Venkateshwara Fast Food  150.0
# 465835          Rohini      Delhi  Jay Mata Ji Home Kitchen  200.0
# 465990          Rohini      Delhi    Shree Ram Paratha Wala  150.0
#
#         Avg ratings  Total ratings                    Food type  \
# ID
# 6745            4.3            100                       Snacks
# 6851            4.3            100             Sweets,Fast Food
# 9757            4.1            100                       Indian
# 12434           3.6            500              Desserts,Sweets
# 32003           4.0           1000    North Indian,South Indian
# ...             ...            ...                          ...
# 366790          4.1            100    Street Food,Indian,Snacks
# 372444          4.1             50    Juices,Beverages,Desserts
# 382460          3.9            100  Indian,Chinese,South Indian
# 465835          2.9             80                 South Indian
# 465990          2.9             80   North Indian,Indian,Snacks
#
#                    Address  Delivery time
# ID
# 6745    Hanuman Tekdi Road             29
# 6851               Jn Road             27
# 9757                   Nsp             27
# 12434             Lbs Marg             25
# 32003           Urdu Galli             28
# ...                    ...            ...
# 366790           Kachiguda             29
# 372444    Paldi & Ambawadi             27
# 382460      Himayath Nagar             27
# 465835              Rohini             28
# 465990              Rohini             28
#
# [94 rows x 9 columns]

# %% [markdown]
# Let's view just the restaurant names, city, and average ratings of the restaurants obtained in our previous query

# %%
df[(df['Delivery time'] < 30) & (df['Price'] < 300)][['Restaurant', 'City', 'Avg ratings']]
# Out:
#                       Restaurant       City  Avg ratings
# ID
# 6745               Tibbs Frankie  Hyderabad          4.3
# 6851             Agrawala Sweets  Hyderabad          4.3
# 9757               Shut Up & Eat      Delhi          4.1
# 12434                 J.J Jalebi     Mumbai          3.6
# 32003                  Rice Bowl  Hyderabad          4.0
# ...                          ...        ...          ...
# 366790        Subbu Mirchi Point  Hyderabad          4.1
# 372444      New Girish Coldrinks  Ahmedabad          4.1
# 382460   Venkateshwara Fast Food  Hyderabad          3.9
# 465835  Jay Mata Ji Home Kitchen      Delhi          2.9
# 465990    Shree Ram Paratha Wala      Delhi          2.9
#
# [94 rows x 3 columns]

# %%
df.loc[(df['Delivery time'] < 30) & (df['Price'] < 300), ['Restaurant', 'City', 'Avg ratings']]
# Out:
# Empty DataFrame
# Columns: [Restaurant, City, Avg ratings]
# Index: []

# %% [markdown]
# Let's find restaurants in the Koramangala region that serve Chinese cuisine

# %%
df[(df['Area'] == 'Koramangala') & (df['Food type'].str.contains('Chinese'))]
# Out:
#                Area       City                    Restaurant    Price  \
# ID
# 211     Koramangala  Bangalore                   Tandoor Hut   255.00
# 435     Koramangala  Bangalore           Bamey'S Restro Cafe   340.00
# 18981   Koramangala  Bangalore              Sultans Of Spice   509.15
# 19172   Koramangala  Bangalore                     30 Square   300.00
# 25222   Koramangala  Bangalore                   China Pearl   935.00
# 28570   Koramangala  Bangalore                   Royal Treat   164.05
# 30732   Koramangala  Bangalore                The Rendezvous   510.00
# 31698   Koramangala  Bangalore                Little Kolkata   255.00
# 36862   Koramangala  Bangalore                   Dice N Dine   425.00
# 56233   Koramangala  Bangalore                   Khawa Karpo   151.30
# 61790   Koramangala  Bangalore          Sardarji Londonwaley   297.50
# 81944   Koramangala  Bangalore                  Nasi And Mee  1020.00
# 131864  Koramangala  Bangalore              Kerala Food Club   212.50
# 151036  Koramangala  Bangalore             Punjabi Unplugged   300.00
# 163740  Koramangala  Bangalore          Darjeeling Hot Momos   212.50
# 175907  Koramangala  Bangalore             Kitchens Of China   350.00
# 192029  Koramangala  Bangalore      Tibetan Mother'S Kitchen   212.50
# 254870  Koramangala  Bangalore            Paratha Experiment   170.00
# 284774  Koramangala  Bangalore  Biergarten Brewery & Kitchen   637.50
# 291520  Koramangala  Bangalore                 Xoox Brewmill   425.00
# 307050  Koramangala  Bangalore                  Call Me Chow   340.00
# 310253  Koramangala  Bangalore                   Globo Combo   300.00
# 316928  Koramangala  Bangalore                  Hungry Chang   280.00
# 328099  Koramangala  Bangalore         Ancient Chinese House   255.00
# 328971  Koramangala  Bangalore             Chuckling Chinese   255.00
# 329149  Koramangala  Bangalore            Imperio Restaurant   300.00
# 335651  Koramangala  Bangalore                    Wok & Talk   300.00
# 336463  Koramangala  Bangalore                Chinese Bistro   200.00
# 345726  Koramangala  Bangalore               Chinese Kitchen   255.00
# 382537  Koramangala  Bangalore        Singh Da Punjabi Dhaba   200.00
# 392828  Koramangala  Bangalore              Big Bowl Company   212.50
# 393402  Koramangala  Bangalore       Friends Euro Restaurant   599.00
# 393835  Koramangala  Bangalore                  The Momo Co.   250.00
# 414306  Koramangala  Bangalore       Food Court By Kitchens@   450.00
# 415302  Koramangala  Bangalore                          Juno   300.00
# 429004  Koramangala  Bangalore             Shehzadas Biryani   297.50
# 437891  Koramangala  Bangalore                    Baba Chill   500.00
# 438411  Koramangala  Bangalore       Lepcha Darjeeling Momos   150.00
# 107301  Koramangala  Bangalore                 Yum In My Tum   200.00
# 366890  Koramangala  Bangalore    Hokart - Special Hot Momos   127.50
#
#         Avg ratings  Total ratings  \
# ID
# 211             4.4            100
# 435             4.4            100
# 18981           4.3             50
# 19172           2.9             80
# 25222           4.5           1000
# 28570           4.1            500
# 30732           4.0             20
# 31698           4.1             20
# 36862           4.0            500
# 56233           4.6            100
# 61790           4.0            500
# 81944           4.6            100
# 131864          4.2            500
# 151036          3.9            500
# 163740          4.2            100
# 175907          2.9             80
# 192029          4.1            500
# 254870          4.3             50
# 284774          4.1            100
# 291520          4.5             20
# 307050          4.3           1000
# 310253          2.9             80
# 316928          3.8            100
# 328099          4.1            100
# 328971          4.1            100
# 329149          3.9            100
# 335651          2.9             80
# 336463          2.9             80
# 345726          4.1            500
# 382537          3.8            100
# 392828          4.1            100
# 393402          2.9             80
# 393835          3.8             50
# 414306          2.9             80
# 415302          2.9             80
# 429004          4.2             20
# 437891          2.9             80
# 438411          2.9             80
# 107301          3.9            500
# 366890          4.3             50
#
#                                                 Food type  \
# ID
# 211             Biryani,Chinese,North Indian,South Indian
# 435                                 Chinese,Thai,Nepalese
# 18981                        North Indian,Chinese,Biryani
# 19172                                             Chinese
# 25222                                       Chinese,Asian
# 28570                North Indian,Chinese,Seafood,Biryani
# 30732                  Continental,Italian,Indian,Chinese
# 31698                        North Indian,Bengali,Chinese
# 36862   American,Asian,Chinese,Continental,Desserts,It...
# 56233                                             Chinese
# 61790         Indian,North Indian,Punjabi,Chinese,Biryani
# 81944   Pan-Asian,Singaporean,Malaysian,Japanese,Asian...
# 131864        Kerala,Chinese,Biryani,Seafood,South Indian
# 151036                North Indian,Chinese,Indian,Mughlai
# 163740                                            Chinese
# 175907                                Chinese,Combo,Asian
# 192029                               Chinese,Tibetan,Thai
# 254870  North Indian,Punjabi,Home Food,Indian,Snacks,C...
# 284774  Continental,Pizzas,North Indian,Chinese,Asian,...
# 291520  North Indian,Chinese,Pizzas,Continental,Desser...
# 307050                                  Chinese,Pan-Asian
# 310253                         Chinese,North Indian,Combo
# 316928                  Chinese,Fast Food,Pan-Asian,Combo
# 328099                                            Chinese
# 328971                                  Chinese,Fast Food
# 329149  Biryani,Mughlai,North Indian,Tandoor,Kerala,Ch...
# 335651                                            Chinese
# 336463                                    Chinese,Biryani
# 345726                                     Chinese,Indian
# 382537                            Punjabi,Tandoor,Chinese
# 392828             North Indian,Chinese,Biryani,Fast Food
# 393402               Chinese,Continental,Indian,Fast Food
# 393835                          Chinese,Pan-Asian,Tibetan
# 414306  North Indian,Biryani,Chinese,Mughlai,Seafood,S...
# 415302          Pan-Asian,Oriental,Chinese,Indian,Persian
# 429004  Biryani,Hyderabadi,Andhra,North Indian,South I...
# 437891                     North Indian,Chinese,Fast Food
# 438411                                            Chinese
# 107301  Chinese,Continental,Beverages,Pizzas,Italian,N...
# 366890               Fast Food,Street Food,Snacks,Chinese
#
#                                   Address  Delivery time  \
# ID
# 211                             5Th Block             69
# 435                             5Th Block             66
# 18981               Koramangala 5Th Block             70
# 19172                Khb Colony 5Th Block             74
# 25222                           6Th Block             74
# 28570               5Th Block Koramangala             64
# 30732               80Ft Road Koramangala             80
# 31698                           5Th Block             69
# 36862           Jyothi Nivas College Road             67
# 56233                         Koramangala             63
# 61790                         Koramangala             65
# 81944                         Koramangala             71
# 131864                    Nanjappa Layout             62
# 151036              Koramangala 1St Block             64
# 163740                        Koramangala             62
# 175907                        Koramangala             66
# 192029                        Koramangala             61
# 254870  Nanjappa Reddy Layout Koramangala             62
# 284774                        Koramangala             72
# 291520                        Koramangala             74
# 307050       Near Licious Koramangala Hub             66
# 310253                        Koramangala             68
# 316928                        Koramangala             67
# 328099                        Koramangala             72
# 328971                        Koramangala             73
# 329149                        Koramangala             66
# 335651                        Koramangala             71
# 336463                        Koramangala             73
# 345726                        Koramangala             75
# 382537                        Koramangala             64
# 392828                        Koramangala             63
# 393402                        Koramangala             75
# 393835                        Koramangala             65
# 414306                        Koramangala             78
# 415302                        Koramangala             78
# 429004                        Koramangala             76
# 437891                        Koramangala             66
# 438411                        Koramangala             68
# 107301                        Koramangala             64
# 366890                        Koramangala             57
#
#         Detailed address available
# ID
# 211                           True
# 435                           True
# 18981                         True
# 19172                         True
# 25222                         True
# 28570                         True
# 30732                         True
# 31698                         True
# 36862                         True
# 56233                        False
# 61790                        False
# 81944                        False
# 131864                        True
# 151036                        True
# 163740                       False
# 175907                       False
# 192029                       False
# 254870                        True
# 284774                       False
# 291520                       False
# 307050                        True
# 310253                       False
# 316928                       False
# 328099                       False
# 328971                       False
# 329149                       False
# 335651                       False
# 336463                       False
# 345726                       False
# 382537                       False
# 392828                       False
# 393402                       False
# 393835                       False
# 414306                       False
# 415302                       False
# 429004                       False
# 437891                       False
# 438411                       False
# 107301                       False
# 366890                       False

# %% [markdown]
# What if we wanted restaurants in Koramangala which exclusively serve Chinese cuisine?

# %%
df[(df['Area'] == 'Koramangala') & (df['Food type'].str.contains('Chinese')) & (~df['Food type'].str.contains(','))]
# Out:
#                Area       City               Restaurant  Price  Avg ratings  \
# ID
# 19172   Koramangala  Bangalore                30 Square  300.0          2.9
# 56233   Koramangala  Bangalore              Khawa Karpo  178.0          4.6
# 163740  Koramangala  Bangalore     Darjeeling Hot Momos  250.0          4.2
# 328099  Koramangala  Bangalore    Ancient Chinese House  300.0          4.1
# 335651  Koramangala  Bangalore               Wok & Talk  300.0          2.9
# 438411  Koramangala  Bangalore  Lepcha Darjeeling Momos  150.0          2.9
#
#         Total ratings Food type               Address  Delivery time
# ID
# 19172              80   Chinese  Khb Colony 5Th Block             64
# 56233             100   Chinese           Koramangala             53
# 163740            100   Chinese           Koramangala             52
# 328099            100   Chinese           Koramangala             62
# 335651             80   Chinese           Koramangala             61
# 438411             80   Chinese           Koramangala             58

# %% [markdown]
# There's been a lot of complaints about restaurants not serving their food on time. We want to increase the delivery time by five minutes to account for any possible delays. Note that the following operation will modify our DataFrame.

# %%
df['Delivery time'] += 5

# %% [markdown]
# Let's run our previous filtering query to inspect these changes

# %%
df[(df['Area'] == 'Koramangala') & (df['Food type'].str.contains('Chinese')) & (~df['Food type'].str.contains(','))]
# Out:
#                Area       City               Restaurant  Price  Avg ratings  \
# ID
# 19172   Koramangala  Bangalore                30 Square  300.0          2.9
# 56233   Koramangala  Bangalore              Khawa Karpo  178.0          4.6
# 163740  Koramangala  Bangalore     Darjeeling Hot Momos  250.0          4.2
# 328099  Koramangala  Bangalore    Ancient Chinese House  300.0          4.1
# 335651  Koramangala  Bangalore               Wok & Talk  300.0          2.9
# 438411  Koramangala  Bangalore  Lepcha Darjeeling Momos  150.0          2.9
#
#         Total ratings Food type               Address  Delivery time
# ID
# 19172              80   Chinese  Khb Colony 5Th Block             74
# 56233             100   Chinese           Koramangala             63
# 163740            100   Chinese           Koramangala             62
# 328099            100   Chinese           Koramangala             72
# 335651             80   Chinese           Koramangala             71
# 438411             80   Chinese           Koramangala             68

# %% [markdown]
# For future verification purposes, let's save this query as a mask

# %%
(df['Area'] == 'Koramangala') & (df['Food type'].str.contains('Chinese')) & (~df['Food type'].str.contains(','))
# Out:
# ID
# 211       False
# 221       False
# 246       False
# 248       False
# 249       False
#           ...
# 464626    False
# 465835    False
# 465872    False
# 465990    False
# 466488    False
# Length: 8680, dtype: bool

# %%
# Mask the query for reusability
mask = (df['Area'] == 'Koramangala') & (df['Food type'].str.contains('Chinese')) & (~df['Food type'].str.contains(','))

# %% [markdown]
# There's a platform-wide discount running for restaurants rated 4.0 or higher. Let's discount all prices by 15%.

# %%
#df.loc['Avg ratings' >= 4.0, 'Price'] *= 0.85  # why won't this work?

# %%
df.loc[df['Avg ratings'] >= 4.0, 'Price']
# Out:
# ID
# 211       255.0
# 221       255.0
# 246       552.5
# 249       297.5
# 254       680.0
#           ...
# 442347    212.5
# 444297    170.0
# 446079    255.0
# 448359    127.5
# 450543     85.0
# Name: Price, Length: 4005, dtype: float64

# %%
df.loc[df['Avg ratings'] >= 4.0, 'Price'] *= 0.85

# %%
df[mask]
# Out:
#                Area       City               Restaurant    Price  Avg ratings  \
# ID
# 19172   Koramangala  Bangalore                30 Square  300.000          2.9
# 56233   Koramangala  Bangalore              Khawa Karpo  128.605          4.6
# 163740  Koramangala  Bangalore     Darjeeling Hot Momos  180.625          4.2
# 328099  Koramangala  Bangalore    Ancient Chinese House  216.750          4.1
# 335651  Koramangala  Bangalore               Wok & Talk  300.000          2.9
# 438411  Koramangala  Bangalore  Lepcha Darjeeling Momos  150.000          2.9
#
#         Total ratings Food type               Address  Delivery time  \
# ID
# 19172              80   Chinese  Khb Colony 5Th Block             74
# 56233             100   Chinese           Koramangala             63
# 163740            100   Chinese           Koramangala             62
# 328099            100   Chinese           Koramangala             72
# 335651             80   Chinese           Koramangala             71
# 438411             80   Chinese           Koramangala             68
#
#         Detailed address available
# ID
# 19172                         True
# 56233                        False
# 163740                       False
# 328099                       False
# 335651                       False
# 438411                       False

# %% [markdown]
# Let's create a new column to indicate if a restaurant has an 'Address' which is different from its 'Area'. Let's call this 'Detailed address available'.

# %%
df['Detailed address available'] = df['Area'] != df['Address']

# %%
df[mask]
# Out:
#                Area       City               Restaurant    Price  Avg ratings  \
# ID
# 19172   Koramangala  Bangalore                30 Square  300.000          2.9
# 56233   Koramangala  Bangalore              Khawa Karpo  128.605          4.6
# 163740  Koramangala  Bangalore     Darjeeling Hot Momos  180.625          4.2
# 328099  Koramangala  Bangalore    Ancient Chinese House  216.750          4.1
# 335651  Koramangala  Bangalore               Wok & Talk  300.000          2.9
# 438411  Koramangala  Bangalore  Lepcha Darjeeling Momos  150.000          2.9
#
#         Total ratings Food type               Address  Delivery time  \
# ID
# 19172              80   Chinese  Khb Colony 5Th Block             74
# 56233             100   Chinese           Koramangala             63
# 163740            100   Chinese           Koramangala             62
# 328099            100   Chinese           Koramangala             72
# 335651             80   Chinese           Koramangala             71
# 438411             80   Chinese           Koramangala             68
#
#         Detailed address available
# ID
# 19172                         True
# 56233                        False
# 163740                       False
# 328099                       False
# 335651                       False
# 438411                       False

# %% [markdown]
# Let's find the average of 'Delivery time' across all restaurants

# %%
df['Delivery time'].mean().round(2)
# Out:
# np.float64(63.97)

# %% [markdown]
# Let's make a new column 'Quality' to categorise each restaurant based on their ratings, using the criteria
# *   'Excellent' if the average rating is at least 4.5
# *   'Good' if the average rating is at least 4.0 but less than 4.5
# *   'Average' if the average rating is at least 3.0 but less than 4.0
# *   'Poor' if the average rating is less than 3.0

# %%
df['Avg ratings'] >= 4.5
# Out:
# ID
# 211       False
# 221       False
# 246       False
# 248       False
# 249       False
#           ...
# 464626    False
# 465835    False
# 465872    False
# 465990    False
# 466488    False
# Name: Avg ratings, Length: 8680, dtype: bool

# %%
df.loc[df['Avg ratings'] >= 4.5,  ['City', 'Area', 'Restaurant']]
# Out:
#              City         Area                 Restaurant
# ID
# 254     Bangalore  Indiranagar                      Treat
# 258     Bangalore  Indiranagar  Chinita Real Mexican Food
# 2811    Bangalore  Ashok Nagar             Art Of Delight
# 3369    Bangalore  Ashok Nagar                   Truffles
# 5172       Mumbai  Bandra Area                  Theobroma
# ...           ...          ...                        ...
# 432094    Kolkata    Esplanade     Keventers Ice Creamery
# 440407    Kolkata    Lake Town             Hunger Twister
# 442032  Bangalore  Koramangala     Keventers Ice Creamery
# 444297  Ahmedabad    Vastrapur                 Chup Chaap
# 450543    Chennai     Perambur                     Afresh
#
# [662 rows x 3 columns]

# %%
def categorise_quality(ratings_row):
    if ratings_row >= 4.5:
        return 'Excellent'
    elif ratings_row >= 4.0:
        return 'Good'
    elif ratings_row >= 3.0:
        return 'Average'
    else:
        return 'Poor'

# %%
df['Avg ratings']
# Out:
# ID
# 211       4.4
# 221       4.1
# 246       4.4
# 248       3.9
# 249       4.0
#          ...
# 464626    2.9
# 465835    2.9
# 465872    2.9
# 465990    2.9
# 466488    2.9
# Name: Avg ratings, Length: 8680, dtype: float64

# %%
#categorise_quality(df['Avg ratings'])  # why won't this work?

# %%
# df['Quality']

# %%
df['Quality'] = df['Avg ratings'].apply(categorise_quality)

# %%
df['Quality']

# %%
df[mask]
# Out:
#                Area       City               Restaurant    Price  Avg ratings  \
# ID
# 19172   Koramangala  Bangalore                30 Square  300.000          2.9
# 56233   Koramangala  Bangalore              Khawa Karpo  128.605          4.6
# 163740  Koramangala  Bangalore     Darjeeling Hot Momos  180.625          4.2
# 328099  Koramangala  Bangalore    Ancient Chinese House  216.750          4.1
# 335651  Koramangala  Bangalore               Wok & Talk  300.000          2.9
# 438411  Koramangala  Bangalore  Lepcha Darjeeling Momos  150.000          2.9
#
#         Total ratings Food type               Address  Delivery time  \
# ID
# 19172              80   Chinese  Khb Colony 5Th Block             74
# 56233             100   Chinese           Koramangala             63
# 163740            100   Chinese           Koramangala             62
# 328099            100   Chinese           Koramangala             72
# 335651             80   Chinese           Koramangala             71
# 438411             80   Chinese           Koramangala             68
#
#         Detailed address available    Quality
# ID
# 19172                         True       Poor
# 56233                        False  Excellent
# 163740                       False       Good
# 328099                       False       Good
# 335651                       False       Poor
# 438411                       False       Poor

# %% [markdown]
# Let's try making another function do to the same thing. However, this time, we will change how the function works internally.

# %%
def categorise_quality_2(row):
    if row['Avg ratings'] >= 4.5:
        return 'Excellent'
    elif row['Avg ratings'] >= 4.0:
        return 'Good'
    elif row['Avg ratings'] >= 3.0:
        return 'Average'
    else:
        return 'Poor'

# %%
#df['Quality 2'] = df['Avg ratings'].apply(categorise_quality_2)  # why won't this work?

# %%
#df['Quality 2'] = df.apply(categorise_quality_2)  # why won't this work?

# %%
# This is the way to pass complete row by using axis = 1
df['Quality 2'] = df.apply(categorise_quality_2, axis = 1)

# %%
df[mask]
# Out:
#                Area       City               Restaurant    Price  Avg ratings  \
# ID
# 19172   Koramangala  Bangalore                30 Square  300.000          2.9
# 56233   Koramangala  Bangalore              Khawa Karpo  128.605          4.6
# 163740  Koramangala  Bangalore     Darjeeling Hot Momos  180.625          4.2
# 328099  Koramangala  Bangalore    Ancient Chinese House  216.750          4.1
# 335651  Koramangala  Bangalore               Wok & Talk  300.000          2.9
# 438411  Koramangala  Bangalore  Lepcha Darjeeling Momos  150.000          2.9
#
#         Total ratings Food type               Address  Delivery time  \
# ID
# 19172              80   Chinese  Khb Colony 5Th Block             74
# 56233             100   Chinese           Koramangala             63
# 163740            100   Chinese           Koramangala             62
# 328099            100   Chinese           Koramangala             72
# 335651             80   Chinese           Koramangala             71
# 438411             80   Chinese           Koramangala             68
#
#         Detailed address available    Quality  Quality 2
# ID
# 19172                         True       Poor       Poor
# 56233                        False  Excellent  Excellent
# 163740                       False       Good       Good
# 328099                       False       Good       Good
# 335651                       False       Poor       Poor
# 438411                       False       Poor       Poor

# %% [markdown]
# Let's count the unique number of words used in naming restaurants across our database

# %%
def unique_name_words(restaurant_name_series):
    restaurant_names = restaurant_name_series.str.split().sum()
    return len(set(restaurant_names))

# %%
print(type(df['Restaurant']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# df['Restaurant'].apply(unique_name_words)  # why won't this work?

# %%
unique_name_words(df['Restaurant'])
# Out:
# 6647
