# %% [markdown]
# Importing the Pandas library

# %%
import pandas as pd

# %% [markdown]
# You can load data into Google Colaboratory in several ways. Note that you need to connect to a runtime before you can load data into Colab. The simplest way is to drag-and-drop your data into the 'Files' section on the toolbar on the left. If you do so, you can consider the file to belong to your root folder; you can access the file without any path prefix.

# %%
# Once you have dragged-and-dropped the file into the 'Files' section, you can access it, with pandas, for instance
df_matches = pd.read_csv('matches_data.csv')
df_matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bengaluru  18-04-2008     League     BB McCullum
# 1  335983  2007/08  Chandigarh  19-04-2008     League      MEK Hussey
# 2  335984  2007/08       Delhi  19-04-2008     League     MF Maharoof
# 3  335985  2007/08      Mumbai  20-04-2008     League      MV Boucher
# 4  335986  2007/08     Kolkata  20-04-2008     League       DJ Hussey
#
#                                         venue      team1      team2  \
# 0                       M Chinnaswamy Stadium  Bengaluru    Kolkata
# 1  Punjab Cricket Association Stadium, Mohali     Punjab    Chennai
# 2                            Feroz Shah Kotla      Delhi  Rajasthan
# 3                            Wankhede Stadium     Mumbai  Bengaluru
# 4                                Eden Gardens    Kolkata  Hyderabad
#
#   toss_winner toss_decision     winner   result  result_margin  target_runs  \
# 0   Bengaluru         field    Kolkata     runs            140          223
# 1     Chennai           bat    Chennai     runs             33          241
# 2   Rajasthan           bat      Delhi  wickets              9          130
# 3      Mumbai           bat  Bengaluru  wickets              5          166
# 4   Hyderabad           bat    Kolkata  wickets              5          111
#
#    target_overs super_over    method    umpire1         umpire2
# 0          20.0          N  standard  Asad Rauf     RE Koertzen
# 1          20.0          N  standard  MR Benson      SL Shastri
# 2          20.0          N  standard  Aleem Dar  GA Pratapkumar
# 3          20.0          N  standard   SJ Davis       DJ Harper
# 4          20.0          N  standard  BF Bowden     K Hariharan

# %%
df_matches.tail(n = 7)
# Out:
#            id season       city        date   match_type player_of_match  \
# 1012  1359542   2023    Kolkata  20-05-2023       League        N Pooran
# 1013  1359543   2023     Mumbai  21-05-2023       League         C Green
# 1014  1359544   2023  Bengaluru  21-05-2023       League    Shubman Gill
# 1015  1370350   2023    Chennai  23-05-2023  Qualifier 1      RD Gaikwad
# 1016  1370351   2023    Chennai  24-05-2023   Eliminator   Akash Madhwal
# 1017  1370352   2023  Ahmedabad  26-05-2023  Qualifier 2    Shubman Gill
# 1018  1370353   2023  Ahmedabad  29-05-2023        Final       DP Conway
#
#                                          venue      team1    team2  \
# 1012                     Eden Gardens, Kolkata    Lucknow  Kolkata
# 1013                  Wankhede Stadium, Mumbai  Hyderabad   Mumbai
# 1014          M Chinnaswamy Stadium, Bengaluru  Bengaluru  Gujarat
# 1015  MA Chidambaram Stadium, Chepauk, Chennai    Chennai  Gujarat
# 1016  MA Chidambaram Stadium, Chepauk, Chennai     Mumbai  Lucknow
# 1017          Narendra Modi Stadium, Ahmedabad    Gujarat   Mumbai
# 1018          Narendra Modi Stadium, Ahmedabad    Gujarat  Chennai
#
#      toss_winner toss_decision   winner   result  result_margin  target_runs  \
# 1012     Kolkata         field  Lucknow     runs              1          177
# 1013      Mumbai         field   Mumbai  wickets              8          201
# 1014     Gujarat         field  Gujarat  wickets              6          198
# 1015     Gujarat         field  Chennai     runs             15          173
# 1016      Mumbai           bat   Mumbai     runs             81          183
# 1017      Mumbai         field  Gujarat     runs             62          234
# 1018     Chennai         field  Chennai  wickets              5          171
#
#       target_overs super_over    method                umpire1      umpire2
# 1012          20.0          N  standard          J Madanagopal    UV Gandhe
# 1013          20.0          N  standard  KN Ananthapadmanabhan    RJ Tucker
# 1014          20.0          N  standard            Nitin Menon    VK Sharma
# 1015          20.0          N  standard           AK Chaudhary  CB Gaffaney
# 1016          20.0          N  standard           BNJ Oxenford    VK Sharma
# 1017          20.0          N  standard            Nitin Menon    RJ Tucker
# 1018          15.0          N       D/L            Nitin Menon    RJ Tucker

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1019 non-null   int64
#  1   season           1019 non-null   object
#  2   city             1019 non-null   object
#  3   date             1019 non-null   object
#  4   match_type       1019 non-null   object
#  5   player_of_match  1019 non-null   object
#  6   venue            1019 non-null   object
#  7   team1            1019 non-null   object
#  8   team2            1019 non-null   object
#  9   toss_winner      1019 non-null   object
#  10  toss_decision    1019 non-null   object
#  11  winner           1019 non-null   object
#  12  result           1019 non-null   object
#  13  result_margin    1019 non-null   int64
#  14  target_runs      1019 non-null   int64
#  15  target_overs     1019 non-null   float64
#  16  super_over       1019 non-null   object
#  17  method           1019 non-null   object
#  18  umpire1          1019 non-null   object
#  19  umpire2          1019 non-null   object
# dtypes: float64(1), int64(3), object(16)
# memory usage: 159.3+ KB

# %%
df_matches.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.019000e+03    1019.000000  1019.000000   1019.000000
# mean   8.684095e+05      16.979392   164.027478     19.760746
# std    3.530975e+05      21.733621    32.225495      1.564372
# min    3.359820e+05       0.000000    43.000000      5.000000
# 25%    5.483135e+05       5.000000   145.000000     20.000000
# 50%    8.298150e+05       8.000000   165.000000     20.000000
# 75%    1.216504e+06      19.000000   185.000000     20.000000
# max    1.370353e+06     146.000000   264.000000     20.000000

# %% [markdown]
# You can also mount your drive and then access files from your drive by running the following code:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1074/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#      94     reply = _read_next_input_message()
#      95     if reply == _NOT_READY or not isinstance(reply, dict):
# ---> 96       time.sleep(0.025)
#      97       continue
#      98     if (
#
# KeyboardInterrupt:

# %% [markdown]
# You can now import data from your drive

# %%
df_google_stock_prices = pd.read_csv('GOOGL_prices.csv')
df_google_stock_prices.head()
# Out:
#        Date    Open    High     Low   Close
# 0  1/3/2006  211.47  218.05  209.32  217.83
# 1  1/4/2006  222.17  224.70  220.09  222.84
# 2  1/5/2006  223.22  226.00  220.97  225.85
# 3  1/6/2006  228.66  235.49  226.85  233.06
# 4  1/9/2006  233.44  236.94  230.70  233.68

# %% [markdown]
# You can unmount your drive in-code using the following:

# %%
drive.flush_and_unmount()

# %% [markdown]
# You can also directly import data from a link as follows:

# %%
# !wget 'https://disk.sample.cat/samples/csv/sample-1.csv'
# Out:
# --2026-04-23 06:01:29--  https://disk.sample.cat/samples/csv/sample-1.csv
# Resolving disk.sample.cat (disk.sample.cat)... 104.21.19.125, 172.67.186.43, 2606:4700:3035::6815:137d, ...
# Connecting to disk.sample.cat (disk.sample.cat)|104.21.19.125|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 319 [application/octet-stream]
# Saving to: ‘sample-1.csv’
#
# sample-1.csv        100%[===================>]     319  --.-KB/s    in 0s
#
# 2026-04-23 06:01:30 (151 MB/s) - ‘sample-1.csv’ saved [319/319]

# %%
df_budget_data = pd.read_csv('sample-1.csv')
df_budget_data.head()
# Out:
#   Task ID;Task Name;Assignee;Status;Due Date;Priority
# 0  1;Research Topic;John Doe;In Progress;2025-02-...
# 1  2;Design Mockup;Jane Smith;Completed;2025-01-2...
# 2  3;Write Code;Mike Lee;Not Started;2025-02-10;High
# 3  4;Review Document;Sarah Kim;In Progress;2025-0...
# 4  5;Test Features;John Doe;Not Started;2025-02-1...

# %%
df_budget_data.tail()
# Out:
#   Task ID;Task Name;Assignee;Status;Due Date;Priority
# 0  1;Research Topic;John Doe;In Progress;2025-02-...
# 1  2;Design Mockup;Jane Smith;Completed;2025-01-2...
# 2  3;Write Code;Mike Lee;Not Started;2025-02-10;High
# 3  4;Review Document;Sarah Kim;In Progress;2025-0...
# 4  5;Test Features;John Doe;Not Started;2025-02-1...

# %%
df_budget_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 1 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Task ID;Task Name;Assignee;Status;Due Date;Priority  5 non-null      object
# dtypes: object(1)
# memory usage: 172.0+ bytes

# %%
df_budget_data.describe()
# Out:
#        Task ID;Task Name;Assignee;Status;Due Date;Priority
# count                                                   5
# unique                                                  5
# top     1;Research Topic;John Doe;In Progress;2025-02-...
# freq                                                    1
