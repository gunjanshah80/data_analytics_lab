# %% [markdown]
# Let's import the Pandas and Seaborn libraries, and the `pyplot` module of the Matplotlib library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Let's load and explore the dataset

# %%
df = pd.read_csv('india_census_2011.csv')
df
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Male_Literate  Female_Literate  \
# 0        870354  474190  396164    439654         282823           156831
# 1        753745  398041  355704    335649         207741           127908
# 2        133487   78971   54516     93770          62834            30936
# 3        140802   77785   63017     86236          56301            29935
# 4        476835  251899  224936    261724         163333            98391
# ..          ...     ...     ...       ...            ...              ...
# 635       41816   19143   22673     36470          16610            19860
# 636      200222   97809  102413    154916          79903            75013
# 637       36842   20727   16115     25332          15397             9935
# 638      105597   54861   50736     78683          43186            35497
# 639      238142  127283  110859    190266         105794            84472
#
#         SC  ...  Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0     1048  ...                            94                           588
# 1      368  ...                           126                           562
# 2      488  ...                            46                           122
# 3       18  ...                            27                           114
# 4      556  ...                            78                           346
# ..     ...  ...                           ...                           ...
# 635    144  ...                          2316                          4309
# 636  35348  ...                          1063                          2408
# 637      0  ...                           685                          1895
# 638      0  ...                           685                          1895
# 639      0  ...                          1371                          3020
#
#      Power_Parity_Rs_150000_240000  Power_Parity_Rs_240000_330000  \
# 0                               71                            101
# 1                               72                             89
# 2                               15                             22
# 3                               12                             18
# 4                               35                             50
# ..                             ...                            ...
# 635                           1370                            838
# 636                            665                            340
# 637                            212                            134
# 638                            212                            134
# 639                            649                            368
#
#      Power_Parity_Rs_150000_330000  Power_Parity_Rs_330000_425000  \
# 0                              172                             74
# 1                              161                             96
# 2                               37                             20
# 3                               30                             19
# 4                               85                             59
# ..                             ...                            ...
# 635                           2208                            576
# 636                           1005                            246
# 637                            346                             70
# 638                            346                             70
# 639                           1017                            265
#
#      Power_Parity_Rs_425000_545000  Power_Parity_Rs_330000_545000  \
# 0                               10                             84
# 1                               28                            124
# 2                               14                             34
# 3                                3                             22
# 4                                8                             67
# ..                             ...                            ...
# 635                            978                           1554
# 636                            483                            729
# 637                            120                            190
# 638                            120                            190
# 639                            497                            762
#
#      Power_Parity_Above_Rs_545000  Total_Power_Parity
# 0                              15                1119
# 1                              18                1066
# 2                              17                 242
# 3                               7                 214
# 4                              12                 629
# ..                            ...                 ...
# 635                          1446               10027
# 636                           341                4890
# 637                            84                3151
# 638                            84                3151
# 639                           376                5782
#
# [640 rows x 118 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
df1 = df[df['Population'] > 6000000]

# %% [markdown]
# Let's make a basic scatter plot

# %%
# Using matplotlib
plt.scatter(data = df1, x = 'State name', y = 'Population')

# %% [markdown]
# The object and it's location in memory is being displayed. We can avoid this in two ways.

# %% [markdown]
# Let's change the size of the image, and also annotate the plot by adding a title and giving names to the axes

# %%
plt.figure(figsize = (12, 3))
plt.scatter(data = df1, x = 'State name', y = 'Population')
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %%
# Using seaborn
sns.scatterplot(data = df1, x = 'State name', y = 'Population')
# Out:
# <Axes: xlabel='State name', ylabel='Population'>

# %%
# Seaborn is built atop matplotlib; many matplotlib methods are compatible with it
plt.figure(figsize = (9, 3))
sns.scatterplot(data = df1, x = 'State name', y = 'Population')
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %% [markdown]
# You can use parameters to customise your plot and make it more interpretable and/or aesthetically pleasing

# %%
plt.figure(figsize = (7, 3))
sns.scatterplot(data = df1, x = 'State name', y = 'Population', s = 10)  # change the size of the markers
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %%
plt.figure(figsize = (7, 3))
sns.scatterplot(data = df1, x = 'State name', y = 'Population', marker = '^')  # change the style of the markers
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %%
plt.figure(figsize = (7, 3))
sns.scatterplot(data = df1, x = 'State name', y = 'Population', c = 'g')  # change the colour of the markers
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %%
plt.figure(figsize = (7, 3))
sns.scatterplot(data = df1, x = 'State name', y = 'Population', alpha = 0.5)  # change the opacity of the markers
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %% [markdown]
# Let's apply all of these changes together

# %%
plt.figure(figsize = (7, 3))
sns.scatterplot(data = df1, x = 'State name', y = 'Population', s = 50, marker = '^', c = 'g', alpha = 0.75)
plt.title('Plot of State and Population')
plt.xlabel('State')
plt.ylabel('Population')
plt.show()

# %% [markdown]
# You may want to change the style of the plots. For instance, the following changes the plot to look more like the plots one obtains by using the ggplot library of the R programming language. This style is often used in academic publications.

# %%
plt.style.use('ggplot')  # changing the plot style to 'ggplot'
plt.figure(figsize = (5, 3))
sns.scatterplot(data = df, x = 'age', y = 'cholestrol', s = 10, marker = '^', c = 'r', alpha = 0.5)
plt.title('Plot of age versus cholesterol levels')
plt.xlabel('Cholesterol')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Style changes are universal and will affect all plots. You need to manually revert the style if they were intended for just one plot.

# %%
plt.style.use('default')  # reverting to the default style
plt.figure(figsize = (5, 3))
sns.scatterplot(data = df, x = 'age', y = 'cholestrol', s = 10, marker = '^', c = 'r', alpha = 0.5)
plt.title('Plot of age versus cholesterol levels')
plt.xlabel('Cholesterol')
plt.ylabel('Age')
plt.show()
